# %%
# Are we able to see any patterns between co2 emissions and summer temperature over a period of 13 years? 2000-2013
#Growing up I remember the summer months of june were always the hottest, and fall weather was always cooler. Over the past several years I've noticed we've been experiencing more indian summers. Can we find data that shows this?Can we see an effect with c02 emissions? 

#create dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as numpy
from scipy.stats import linregress

#import csv files
co2_csv="..\Resources\CO_level_2000.csv"
temp_csv="..\Resources\GlobalLandTemperaturesByState.csv"
global_emissions = "..\Resources\GlobalEmissions1751_2014.csv"
global_temp = "..\Resources\GlobalLandTemperaturesByCountry.csv"



co2_data = pd.read_csv(co2_csv)
temp_data = pd.read_csv(temp_csv)
Global_df = pd.read_csv(global_emissions) 
global_temp = pd.read_csv(global_temp)

#turn csv into a dataframe
temp_df = pd.DataFrame(temp_data)
co2_data= pd.DataFrame(co2_data)
global_temp_df = pd.DataFrame(global_temp)

#remove null values
temp_df = temp_df.dropna(how="any")
co2_data = co2_data.dropna(how="any")

#verify successful import and conversion
# print(temp_df.head())
# print(co2_data.head())

global_temp.loc[global_temp["Country"]=="United States"]
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 554880  1768-09-01              15.420                          2.880
# 554881  1768-10-01               8.162                          3.386
# 554882  1768-11-01               1.591                          3.783
# 554883  1768-12-01              -2.882                          4.979
# 554884  1769-01-01              -3.952                          4.856
# 554885  1769-02-01              -2.684                          3.311
# 554886  1769-03-01               1.828                          3.884
# 554887  1769-04-01               8.843                          3.482
# 554888  1769-05-01              15.724                          4.795
# 554889  1769-06-01              20.933                          2.613
# 554890  1769-07-01              22.093                          3.277
# 554891  1769-08-01              20.787                          3.329
# 554892  1769-09-01                 NaN                            NaN
# 554893  1769-10-01                 NaN                            NaN
# 554894  1769-11-01                 NaN                            NaN
# 554895  1769-12-01                 NaN                            NaN
# 554896  1770-01-01                 NaN                            NaN
# 554897  1770-02-01                 NaN                            NaN
# 554898  1770-03-01                 NaN                            NaN
# 554899  1770-04-01                 NaN                            NaN
# 554900  1770-05-01                 NaN                            NaN
# 554901  1770-06-01                 NaN                            NaN
# 554902  1770-07-01                 NaN                            NaN
# 554903  1770-08-01                 NaN                            NaN
# 554904  1770-09-01                 NaN                            NaN
# 554905  1770-10-01                 NaN                            NaN
# 554906  1770-11-01                 NaN                            NaN
# 554907  1770-12-01                 NaN                            NaN
# 554908  1771-01-01                 NaN                            NaN
# 554909  1771-02-01                 NaN                            NaN
# ...            ...                 ...                            ...
# 557791  2011-04-01               8.582                          0.158
# 557792  2011-05-01              13.759                          0.183
# 557793  2011-06-01              19.578                          0.251
# 557794  2011-07-01              22.722                          0.220
# 557795  2011-08-01              21.915                          0.132
# 557796  2011-09-01              17.148                          0.110
# 557797  2011-10-01              10.490                          0.134
# 557798  2011-11-01               2.966                          0.186
# 557799  2011-12-01              -0.635                          0.253
# 557800  2012-01-01              -2.268                          0.232
# 557801  2012-02-01               0.582                          0.182
# 557802  2012-03-01               6.024                          0.138
# 557803  2012-04-01              10.196                          0.278
# 557804  2012-05-01              15.422                          0.196
# 557805  2012-06-01              19.954                          0.273
# 557806  2012-07-01              23.008                          0.278
# 557807  2012-08-01              21.422                          0.251
# 557808  2012-09-01              17.036                          0.185
# 557809  2012-10-01               9.688                          0.225
# 557810  2012-11-01               3.330                          0.120
# 557811  2012-12-01              -1.261                          0.228
# 557812  2013-01-01              -2.155                          0.185
# 557813  2013-02-01              -1.216                          0.216
# 557814  2013-03-01               2.289                          0.222
# 557815  2013-04-01               6.970                          0.221
# 557816  2013-05-01              14.073                          0.178
# 557817  2013-06-01              20.198                          0.236
# 557818  2013-07-01              22.074                          0.152
# 557819  2013-08-01              21.168                          0.249
# 557820  2013-09-01              18.273                          1.210
#
#               Country
# 554880  United States
# 554881  United States
# 554882  United States
# 554883  United States
# 554884  United States
# 554885  United States
# 554886  United States
# 554887  United States
# 554888  United States
# 554889  United States
# 554890  United States
# 554891  United States
# 554892  United States
# 554893  United States
# 554894  United States
# 554895  United States
# 554896  United States
# 554897  United States
# 554898  United States
# 554899  United States
# 554900  United States
# 554901  United States
# 554902  United States
# 554903  United States
# 554904  United States
# 554905  United States
# 554906  United States
# 554907  United States
# 554908  United States
# 554909  United States
# ...               ...
# 557791  United States
# 557792  United States
# 557793  United States
# 557794  United States
# 557795  United States
# 557796  United States
# 557797  United States
# 557798  United States
# 557799  United States
# 557800  United States
# 557801  United States
# 557802  United States
# 557803  United States
# 557804  United States
# 557805  United States
# 557806  United States
# 557807  United States
# 557808  United States
# 557809  United States
# 557810  United States
# 557811  United States
# 557812  United States
# 557813  United States
# 557814  United States
# 557815  United States
# 557816  United States
# 557817  United States
# 557818  United States
# 557819  United States
# 557820  United States
#
# [2941 rows x 4 columns]

# %%
#Figure out what we're working with. Only print first city and see how many years of data there are.

print(temp_df.loc[(temp_df['State']=="California")])
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty  \
# 71058  1849-01-01               5.591                          2.405
# 71059  1849-02-01               6.941                          2.041
# 71060  1849-03-01               9.731                          2.294
# 71061  1849-04-01              12.294                          2.861
# 71062  1849-05-01              14.417                          2.215
# 71063  1849-06-01              21.091                          2.635
# 71064  1849-07-01              25.556                          3.960
# 71065  1849-08-01              24.992                          3.828
# 71066  1849-09-01              20.499                          1.880
# 71067  1849-10-01              14.725                          2.134
# 71068  1849-11-01               8.506                          1.953
# 71069  1849-12-01               3.898                          1.772
# 71070  1850-01-01               4.261                          2.381
# 71071  1850-02-01               6.284                          1.882
# 71072  1850-03-01               8.171                          3.363
# 71073  1850-04-01              12.680                          2.543
# 71074  1850-05-01              16.217                          1.058
# 71075  1850-06-01              20.183                          1.339
# 71076  1850-07-01              23.411                          1.566
# 71077  1850-08-01              24.874                          2.216
# 71078  1850-09-01              21.073                          1.806
# 71079  1850-10-01              15.592                          1.266
# 71080  1850-11-01               8.356                          1.999
# 71081  1850-12-01               3.513                          1.136
# 71082  1851-01-01               5.070                          2.788
# 71083  1851-02-01               6.228                          1.362
# 71084  1851-03-01               9.357                          1.284
# 71085  1851-04-01              13.462                          1.927
# 71086  1851-05-01              16.256                          1.252
# 71087  1851-06-01              21.385                          1.264
# ...           ...                 ...                            ...
# 73005  2011-04-01              12.175                          0.181
# 73006  2011-05-01              14.375                          0.175
# 73007  2011-06-01              19.500                          0.237
# 73008  2011-07-01              23.461                          0.304
# 73009  2011-08-01              24.032                          0.281
# 73010  2011-09-01              22.427                          0.178
# 73011  2011-10-01              16.254                          0.189
# 73012  2011-11-01               9.091                          0.215
# 73013  2011-12-01               6.257                          0.297
# 73014  2012-01-01               7.981                          0.264
# 73015  2012-02-01               8.224                          0.206
# 73016  2012-03-01               9.758                          0.168
# 73017  2012-04-01              13.483                          0.315
# 73018  2012-05-01              17.957                          0.216
# 73019  2012-06-01              20.792                          0.280
# 73020  2012-07-01              23.765                          0.359
# 73021  2012-08-01              25.407                          0.230
# 73022  2012-09-01              22.760                          0.211
# 73023  2012-10-01              16.638                          0.280
# 73024  2012-11-01              11.475                          0.237
# 73025  2012-12-01               6.062                          0.323
# 73026  2013-01-01               5.607                          0.260
# 73027  2013-02-01               7.521                          0.275
# 73028  2013-03-01              12.415                          0.251
# 73029  2013-04-01              14.707                          0.283
# 73030  2013-05-01              17.899                          0.228
# 73031  2013-06-01              22.513                          0.265
# 73032  2013-07-01              25.563                          0.206
# 73033  2013-08-01              23.460                          0.369
# 73034  2013-09-01              21.924                          0.861
#
#             State        Country
# 71058  California  United States
# 71059  California  United States
# 71060  California  United States
# 71061  California  United States
# 71062  California  United States
# 71063  California  United States
# 71064  California  United States
# 71065  California  United States
# 71066  California  United States
# 71067  California  United States
# 71068  California  United States
# 71069  California  United States
# 71070  California  United States
# 71071  California  United States
# 71072  California  United States
# 71073  California  United States
# 71074  California  United States
# 71075  California  United States
# 71076  California  United States
# 71077  California  United States
# 71078  California  United States
# 71079  California  United States
# 71080  California  United States
# 71081  California  United States
# 71082  California  United States
# 71083  California  United States
# 71084  California  United States
# 71085  California  United States
# 71086  California  United States
# 71087  California  United States
# ...           ...            ...
# 73005  California  United States
# 73006  California  United States
# 73007  California  United States
# 73008  California  United States
# 73009  California  United States
# 73010  California  United States
# 73011  California  United States
# 73012  California  United States
# 73013  California  United States
# 73014  California  United States
# 73015  California  United States
# 73016  California  United States
# 73017  California  United States
# 73018  California  United States
# 73019  California  United States
# 73020  California  United States
# 73021  California  United States
# 73022  California  United States
# 73023  California  United States
# 73024  California  United States
# 73025  California  United States
# 73026  California  United States
# 73027  California  United States
# 73028  California  United States
# 73029  California  United States
# 73030  California  United States
# 73031  California  United States
# 73032  California  United States
# 73033  California  United States
# 73034  California  United States
#
# [1977 rows x 5 columns]

# %%
print("Looking at the data above we can see that this data has state temp data starting from 1849 to 2013")
# Out:
# Looking at the data above we can see that this data has state temp data starting from 1849 to 2013

# %%
#Begin Datacleaning

# %%
Global_df.head()
# Out:
#                                               Nation    Year  \
# 0              (Note: missing values denoted by ".")     NaN
# 1  Source: Tom Boden and Bob Andres (Oak Ridge Na...     NaN
# 2                     DOI: 10.3334/CDIAC/00001_V2017     NaN
# 3                                        AFGHANISTAN  1949.0
# 4                                        AFGHANISTAN  1950.0
#
#    Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                4.0
# 4                                               23.0
#
#   Emissions from solid fuel consumption  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                     4
# 4                                     6
#
#   Emissions from liquid fuel consumption Emissions from gas fuel consumption  \
# 0                                    NaN                                 NaN
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                      0                                   0
# 4                                     18                                   0
#
#    Emissions from cement production Emissions from gas flaring  \
# 0                               NaN                        NaN
# 1                               NaN                        NaN
# 2                               NaN                        NaN
# 3                               0.0                          .
# 4                               0.0                          0
#
#   Per capita CO2 emissions (metric tons of carbon)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                                .
# 4                                                0
#
#    Emissions from bunker fuels (not included in the totals)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                0.0
# 4                                                0.0

# %%
#filter the tempstate data by country. Filter to U.S.

# us_states_df = temp_df.loc[temp_df["Country"] == "United States"]
# print(us_states_df.head())

#use this for code below

# %%
#create a for loop to iterate over the years
start_year = 1849
end_year = 2013


# #to input the incremental years from 1849 to 2013,created a for loop  
# Summer month is June so using the string 6 on date
for year in range(start_year, end_year + 1): 
    temp_df.loc[temp_df['dt'].str.contains(str(year)+ "-06"), 'Year'] = str(year)
   # temp_df.loc[temp_df['dt'].str.contains(str(year)), 'Year'] = str(year)
    
temp_df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty State  \
# 0  1855-05-01              25.544                          1.171  Acre
# 1  1855-06-01              24.228                          1.103  Acre
# 2  1855-07-01              24.371                          1.044  Acre
# 3  1855-08-01              25.427                          1.073  Acre
# 4  1855-09-01              25.675                          1.014  Acre
#
#   Country  Year
# 0  Brazil   NaN
# 1  Brazil  1855
# 2  Brazil   NaN
# 3  Brazil   NaN
# 4  Brazil   NaN

# %%
temp_df = temp_df.dropna(how="any")

# %%
us_states_df = temp_df.loc[temp_df["Country"] == "United States"]
print(us_states_df)
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 8725    1849-06-01              24.903                          2.066
# 8737    1850-06-01              24.388                          1.000
# 8749    1851-06-01              24.387                          1.206
# 8761    1852-06-01              23.968                          1.054
# 8773    1853-06-01              25.156                          0.984
# 8785    1854-06-01              25.087                          1.634
# 8797    1855-06-01              23.798                          1.277
# 8809    1856-06-01              25.922                          1.667
# 8821    1857-06-01              23.935                          0.824
# 8833    1858-06-01              24.602                          1.413
# 8845    1859-06-01              24.736                          1.401
# 8857    1860-06-01              25.655                          0.961
# 8869    1861-06-01              25.572                          1.708
# 8881    1862-06-01              24.468                          1.781
# 8893    1863-06-01              23.615                          1.859
# 8905    1864-06-01              24.299                          1.472
# 8917    1865-06-01              25.535                          1.337
# 8929    1866-06-01              24.316                          0.896
# 8941    1867-06-01              25.008                          0.921
# 8953    1868-06-01              24.905                          0.732
# 8965    1869-06-01              24.230                          0.942
# 8977    1870-06-01              24.193                          1.273
# 8989    1871-06-01              25.537                          0.780
# 9001    1872-06-01              25.396                          0.822
# 9013    1873-06-01              25.095                          0.566
# 9025    1874-06-01              26.002                          0.922
# 9037    1875-06-01              25.446                          1.196
# 9049    1876-06-01              24.820                          0.779
# 9061    1877-06-01              25.425                          1.841
# 9073    1878-06-01              24.598                          1.325
# ...            ...                 ...                            ...
# 626088  1984-06-01              13.798                          0.187
# 626100  1985-06-01              14.816                          0.296
# 626112  1986-06-01              17.084                          0.152
# 626124  1987-06-01              15.819                          0.170
# 626136  1988-06-01              19.119                          0.257
# 626148  1989-06-01              14.076                          0.215
# 626160  1990-06-01              15.456                          0.300
# 626172  1991-06-01              15.190                          0.076
# 626184  1992-06-01              14.770                          0.199
# 626196  1993-06-01              12.597                          0.142
# 626208  1994-06-01              16.369                          0.225
# 626220  1995-06-01              13.089                          0.144
# 626232  1996-06-01              16.053                          0.189
# 626244  1997-06-01              15.691                          0.143
# 626256  1998-06-01              11.565                          0.178
# 626268  1999-06-01              13.930                          0.253
# 626280  2000-06-01              14.827                          0.169
# 626292  2001-06-01              15.641                          0.197
# 626304  2002-06-01              16.500                          0.122
# 626316  2003-06-01              13.619                          0.265
# 626328  2004-06-01              13.868                          0.260
# 626340  2005-06-01              14.198                          0.151
# 626352  2006-06-01              17.172                          0.253
# 626364  2007-06-01              16.410                          0.175
# 626376  2008-06-01              13.860                          0.150
# 626388  2009-06-01              13.299                          0.113
# 626400  2010-06-01              14.453                          0.188
# 626412  2011-06-01              13.953                          0.255
# 626424  2012-06-01              17.366                          0.239
# 626436  2013-06-01              16.267                          0.276
#
#           State        Country  Year
# 8725    Alabama  United States  1849
# 8737    Alabama  United States  1850
# 8749    Alabama  United States  1851
# 8761    Alabama  United States  1852
# 8773    Alabama  United States  1853
# 8785    Alabama  United States  1854
# 8797    Alabama  United States  1855
# 8809    Alabama  United States  1856
# 8821    Alabama  United States  1857
# 8833    Alabama  United States  1858
# 8845    Alabama  United States  1859
# 8857    Alabama  United States  1860
# 8869    Alabama  United States  1861
# 8881    Alabama  United States  1862
# 8893    Alabama  United States  1863
# 8905    Alabama  United States  1864
# 8917    Alabama  United States  1865
# 8929    Alabama  United States  1866
# 8941    Alabama  United States  1867
# 8953    Alabama  United States  1868
# 8965    Alabama  United States  1869
# 8977    Alabama  United States  1870
# 8989    Alabama  United States  1871
# 9001    Alabama  United States  1872
# 9013    Alabama  United States  1873
# 9025    Alabama  United States  1874
# 9037    Alabama  United States  1875
# 9049    Alabama  United States  1876
# 9061    Alabama  United States  1877
# 9073    Alabama  United States  1878
# ...         ...            ...   ...
# 626088  Wyoming  United States  1984
# 626100  Wyoming  United States  1985
# 626112  Wyoming  United States  1986
# 626124  Wyoming  United States  1987
# 626136  Wyoming  United States  1988
# 626148  Wyoming  United States  1989
# 626160  Wyoming  United States  1990
# 626172  Wyoming  United States  1991
# 626184  Wyoming  United States  1992
# 626196  Wyoming  United States  1993
# 626208  Wyoming  United States  1994
# 626220  Wyoming  United States  1995
# 626232  Wyoming  United States  1996
# 626244  Wyoming  United States  1997
# 626256  Wyoming  United States  1998
# 626268  Wyoming  United States  1999
# 626280  Wyoming  United States  2000
# 626292  Wyoming  United States  2001
# 626304  Wyoming  United States  2002
# 626316  Wyoming  United States  2003
# 626328  Wyoming  United States  2004
# 626340  Wyoming  United States  2005
# 626352  Wyoming  United States  2006
# 626364  Wyoming  United States  2007
# 626376  Wyoming  United States  2008
# 626388  Wyoming  United States  2009
# 626400  Wyoming  United States  2010
# 626412  Wyoming  United States  2011
# 626424  Wyoming  United States  2012
# 626436  Wyoming  United States  2013
#
# [8379 rows x 6 columns]

# %%
us_states_df["AverageTemperature"] =(us_states_df["AverageTemperature"]*1.8+32)
us_states_df = us_states_df[["AverageTemperature","State","Year"]]
us_states_df.head()
# Out:
# C:\Users\Mikey\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#       AverageTemperature    State  Year
# 8725             76.8254  Alabama  1849
# 8737             75.8984  Alabama  1850
# 8749             75.8966  Alabama  1851
# 8761             75.1424  Alabama  1852
# 8773             77.2808  Alabama  1853

# %%
#Now need to clean cO2 data more in order to merge together
co2_data.columns
# Out:
# Index(['Unnamed: 0', 'State Code', 'County Code', 'Site Num', 'Address',
#        'State', 'County', 'City', 'Date', 'Arithmetic Mean',
#        'Units of Measure', '1st Max Value', '1st Max Hour', 'AQI'],
#       dtype='object')

# %%
co2_data = co2_data[["State","City","Date","Arithmetic Mean","Units of Measure"]]

# %%
start_year = 2000
end_year = 2013

# #to input the incremental years from 1849 to 2013,created a for loop  
for year in range(start_year, end_year + 1): 
    co2_data.loc[co2_data['Date'].str.contains(str(year)), 'Year'] = str(year)

co2_data.head()
# Out:
#        State        City        Date  Arithmetic Mean   Units of Measure  Year
# 366  Alabama  Birmingham  2000-01-01         0.994737  Parts per million  2000
# 367  Alabama  Birmingham  2000-01-02         0.891667  Parts per million  2000
# 368  Alabama  Birmingham  2000-01-03         0.700000  Parts per million  2000
# 369  Alabama  Birmingham  2000-01-04         1.120833  Parts per million  2000
# 370  Alabama  Birmingham  2000-01-05         1.095833  Parts per million  2000

# %%
#group cities by state and year  and find the mean c02 emission of each year
## GRouping all cities together per state and giving that an average
#Major assumption but it's a starting point


co2_group = co2_data.groupby(["State","Year"], as_index=False)
co2_group_mean = co2_group.mean()
co2_group_mean.head()
# Out:
#      State  Year  Arithmetic Mean
# 0  Alabama  2000         0.980286
# 1  Alabama  2001         1.200558
# 2  Alabama  2002         0.689120
# 3  Alabama  2003         0.413722
# 4  Alabama  2004         0.532250

# %% [markdown]
# co2_group_mean.merge(us_states_df,on=["State","Year"])

# %%
co2_temp_clean = co2_group_mean.merge(us_states_df,on=["State","Year"])
co2_temp_clean = co2_temp_clean.rename(columns={"Arithmetic Mean":"C02 emmision (ppm)"})
co2_temp_clean.head()
# Out:
#      State  Year  C02 emmision (ppm)  AverageTemperature
# 0  Alabama  2000            0.980286             78.5084
# 1  Alabama  2001            1.200558             76.8272
# 2  Alabama  2002            0.689120             78.2654
# 3  Alabama  2003            0.413722             76.6130
# 4  Alabama  2004            0.532250             77.8388

# %%
#now need to figure out how to graph ALL data... start by individual cities?

# %%
cali = co2_temp_clean.loc[co2_temp_clean["State"]=="California"]
cali
# Out:
#          State  Year  C02 emmision (ppm)  AverageTemperature
# 56  California  2000            0.671920             72.4730
# 57  California  2001            0.632294             71.5676
# 58  California  2002            0.586028             71.3138
# 59  California  2003            0.546070             71.3336
# 60  California  2004            0.484930             70.5326
# 61  California  2005            0.459569             66.5060
# 62  California  2006            0.464194             73.3496
# 63  California  2007            0.435249             70.6442
# 64  California  2008            0.409369             71.2886
# 65  California  2009            0.370645             67.7192
# 66  California  2010            0.344896             69.1970
# 67  California  2011            0.362106             67.1000
# 68  California  2012            0.351630             69.4256
# 69  California  2013            0.343875             72.5234

# %%
fig= plt.figure(figsize=(15,5))

# (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x,y)
# regress_values = cali["Year"] * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

x_values = cali["Year"].astype('int64')
y_values = cali["AverageTemperature"]


plt.xlabel("Year")
plt.ylabel("June Temperature (F)")
plt.title("Yearly Summer Time Temperature of California")
plt.scatter(x_values,y_values)
#plt.subplot(1,2,2)


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


linregress(x_values,regress_values)
plt.plot(x_values, intercept + slope*x_values, 'r', label='fitted line')
plt.annotate(line_eq,(2000,67),fontsize=15,color="red")
plt.grid(True)

# Save the figure
plt.savefig("output_data/cali_temp.png")


# plt.plot(cali["Year"],regress_values,"r-")
# plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# %%
#looks like the temp is going on a downward trend, is this signifying that temperature is changing? Can test by looking at a different month.

# %%
fig= plt.figure(figsize=(15,5))
plt.xlabel("Year")
plt.ylabel("CO2 emission (ppm)")
plt.title("CO2 Emissions For California from 2000-2013")
plt.grid(True)


plt.scatter(cali["Year"],cali["C02 emmision (ppm)"])

# Save the figure
plt.savefig("output_data/cali_co2.png")

# %%
print("It appears that California has been doing there part to reduce it's greenhouse emissions")

# %%
us_states_df['State'].value_counts()

# for state in States:
#     if state = state
# Out:
# Missouri                165
# Wyoming                 165
# Vermont                 165
# California              165
# Maine                   165
# Kansas                  165
# Arizona                 165
# Arkansas                165
# Virginia                165
# Mississippi             165
# New Jersey              165
# Utah                    165
# South Dakota            165
# Iowa                    165
# Maryland                165
# Pennsylvania            165
# South Carolina          165
# District Of Columbia    165
# Kentucky                165
# Indiana                 165
# Alabama                 165
# Nebraska                165
# Idaho                   165
# Connecticut             165
# Ohio                    165
# Georgia (State)         165
# Louisiana               165
# Montana                 165
# North Dakota            165
# Nevada                  165
# Oregon                  165
# New Hampshire           165
# Texas                   165
# Tennessee               165
# Colorado                165
# New York                165
# North Carolina          165
# Minnesota               165
# Washington              165
# Rhode Island            165
# Michigan                165
# Florida                 165
# Wisconsin               165
# Illinois                165
# New Mexico              165
# West Virginia           165
# Oklahoma                165
# Massachusetts           165
# Delaware                165
# Alaska                  163
# Hawaii                  131
# Name: State, dtype: int64

# %%
#temp of New York in June
#Get data for New York

ny = co2_temp_clean.loc[co2_temp_clean["State"]=="New York"]

#x_values2 = cali["Year"].astype('int64')
y_values2 = ny["AverageTemperature"]

fig= plt.figure(figsize=(15,5))
plt.xlabel("Year")
plt.ylabel("June Temperature (F)")
plt.title("Yearly Summer Time Temperature of New York")
plt.scatter(x_values,y_values2)
#plt.subplot(1,2,2)


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values2)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.grid(True)


linregress(x_values,regress_values)
plt.plot(x_values, intercept + slope*x_values, 'r', label='fitted line')
plt.annotate(line_eq,(2000,67),fontsize=15,color="red")

# Save the figure
plt.savefig("output_data/ny_temp.png")

# %%
fig= plt.figure(figsize=(15,5))
plt.xlabel("Year")
plt.ylabel("CO2 emission (ppm)")
plt.title("CO2 Emissions For New York from 2000-2013")
plt.grid(True)


plt.scatter(ny["Year"],ny["C02 emmision (ppm)"])

# Save the figure
plt.savefig("output_data/ny_co2.png")

# %%
#temp of Alaska in June
#Get data for Alaska

alaska = co2_temp_clean.loc[co2_temp_clean["State"]=="Alaska"]

#x_values2 = cali["Year"].astype('int64')
y_values3 = alaska["AverageTemperature"]

fig= plt.figure(figsize=(15,5))
plt.xlabel("Year")
plt.ylabel("June Temperature (F)")
plt.title("Yearly Summer Time Temperature of Alaska")
plt.scatter(x_values,y_values3)
plt.grid(True)

#plt.subplot(1,2,2)


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values3)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


linregress(x_values,regress_values)
plt.plot(x_values, intercept + slope*x_values, 'r', label='fitted line')
plt.annotate(line_eq,(2000,54),fontsize=15,color="red")

# Save the figure
plt.savefig("output_data/alaska_temp.png")

# %%
fig= plt.figure(figsize=(15,5))
plt.xlabel("Year")
plt.ylabel("CO2 emission (ppm)")
plt.title("CO2 Emissions For Alaska from 2000-2013")
plt.grid(True)


plt.scatter(alaska["Year"],alaska["C02 emmision (ppm)"])
# Save the figure
plt.savefig("output_data/alaska_co2.png")

# %%
hawaii = co2_temp_clean.loc[co2_temp_clean["State"]=="Hawaii"]

#x_values2 = cali["Year"].astype('int64')
y_values4 = hawaii["AverageTemperature"]

fig= plt.figure(figsize=(15,5))
plt.xlabel("Year")
plt.ylabel("June Temperature (F)")
plt.title("Yearly Summer Time Temperature of Hawaii")
plt.scatter(x_values,y_values4)
plt.grid(True)
#plt.subplot(1,2,2)


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values4)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


linregress(x_values,regress_values)
plt.plot(x_values, intercept + slope*x_values, 'r', label='fitted line')
plt.annotate(line_eq,(2000,74),fontsize=15,color="red")

# Save the figure
plt.savefig("output_data/hawaii_temp.png")

# %%
fig= plt.figure(figsize=(15,5))
plt.xlabel("Year")
plt.ylabel("CO2 emission (ppm)")
plt.title("CO2 Emissions For Hawaii from 2000-2013")
plt.grid(True)


plt.scatter(hawaii["Year"],hawaii["C02 emmision (ppm)"])

# Save the figure
plt.savefig("output_data/hawaii_co2.png")

# %%
florida = co2_temp_clean.loc[co2_temp_clean["State"]=="Florida"]

#x_values2 = cali["Year"].astype('int64')
y_values5 = florida["AverageTemperature"]

fig= plt.figure(figsize=(15,5))
plt.xlabel("Year")
plt.ylabel("June Temperature (F)")
plt.title("Yearly Summer Time Temperature of Florida")
plt.scatter(x_values,y_values5)
plt.grid(True)
#plt.subplot(1,2,2)


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values5)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


linregress(x_values,regress_values)
plt.plot(x_values, intercept + slope*x_values, 'r', label='fitted line')
plt.annotate(line_eq,(2000,82),fontsize=15,color="red")

# Save the figure
plt.savefig("output_data/florida_temp.png")

# %%
fig= plt.figure(figsize=(15,5))
plt.xlabel("Year")
plt.ylabel("CO2 emission (ppm)")
plt.title("CO2 Emissions For Hawaii from 2000-2013")
plt.grid(True)


plt.scatter(florida["Year"],florida["C02 emmision (ppm)"])
# Save the figure
plt.savefig("output_data/florida_co2.png")
